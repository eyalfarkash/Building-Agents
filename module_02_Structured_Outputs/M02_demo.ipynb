# %% [markdown]
# # Structured Outputs
# This notebook demonstrates how to work with different output formats and parsers when working with Language Models (LLM).
#
# ## What we'll learn:
# - Basic string output parsing
# - Working with tools and structured outputs
# - Using Pydantic models for type validation
# - Understanding different parser types and their use cases

# %% [markdown]
# ### Setup

# %%
from typing import Annotated
from pydantic import BaseModel, Field
from dotenv import load_dotenv
from lib.messages import UserMessage, SystemMessage
from lib.tooling import tool
from lib.llm import LLM
from lib.parsers import (
    StrOutputParser,
    JsonOutputParser, 
    PydanticOutputParser, 
    ToolOutputParser,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 from lib.messages import UserMessage, SystemMessage
#       5 from lib.tooling import tool
# ----> 6 from lib.llm import LLM
#       7 from lib.parsers import (
#       8     StrOutputParser,
#       9     JsonOutputParser,
#      10     PydanticOutputParser,
#      11     ToolOutputParser,
#      12 )
#
# File c:\Accenture\One-drive\OneDrive - Accenture\8-Eyal_study_at_accenture\Building-Agents\Building-Agents\module_02_Structured_Outputs\lib\llm.py:3
#       1 from typing import List, Optional, Dict, Any
#       2 from pydantic import BaseModel
# ----> 3 from openai import OpenAI
#       4 from lib.messages import (
#       5     AnyMessage,
#       6     AIMessage,
#       7     BaseMessage,
#       8     UserMessage,
#       9 )
#      10 from lib.tooling import Tool
#
# File c:\Users\eyal.farkash\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\__init__.py:8
#       5 import os as _os
#       6 from typing_extensions import override
# ----> 8 from . import types
#       9 from ._types import NOT_GIVEN, Omit, NoneType, NotGiven, Transport, ProxiesTypes
#      10 from ._utils import file_from_path
#
# File c:\Users\eyal.farkash\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\types\__init__.py:5
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
#       3 from __future__ import annotations
# ----> 5 from .batch import Batch as Batch
#       6 from .image import Image as Image
#       7 from .model import Model as Model
#
# File c:\Users\eyal.farkash\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\types\batch.py:6
#       3 from typing import List, Optional
#       4 from typing_extensions import Literal
# ----> 6 from .._models import BaseModel
#       7 from .batch_error import BatchError
#       8 from .shared.metadata import Metadata
#
# File c:\Users\eyal.farkash\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_models.py:26
#      23 import pydantic.generics
#      24 from pydantic.fields import FieldInfo
# ---> 26 from ._types import (
#      27     Body,
#      28     IncEx,
#      29     Query,
#      30     ModelT,
#      31     Headers,
#      32     Timeout,
#      33     NotGiven,
#      34     AnyMapping,
#      35     HttpxRequestFiles,
#      36 )
#      37 from ._utils import (
#      38     PropertyInfo,
#      39     is_list,
#    (...)     51     strip_annotated_type,
#      52 )
#      53 from ._compat import (
#      54     PYDANTIC_V2,
#      55     ConfigDict,
#    (...)     64     field_get_default,
#      65 )
#
# File c:\Users\eyal.farkash\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_types.py:21
#       4 from typing import (
#       5     IO,
#       6     TYPE_CHECKING,
#    (...)     17     Sequence,
#      18 )
#      19 from typing_extensions import Set, Literal, Protocol, TypeAlias, TypedDict, override, runtime_checkable
# ---> 21 import httpx
#      22 import pydantic
#      23 from httpx import URL, Proxy, Timeout, Response, BaseTransport, AsyncBaseTransport
#
# File c:\Users\eyal.farkash\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\__init__.py:2
#       1 from .__version__ import __description__, __title__, __version__
# ----> 2 from ._api import delete, get, head, options, patch, post, put, request, stream
#       3 from ._auth import Auth, BasicAuth, DigestAuth
#       4 from ._client import USE_CLIENT_DEFAULT, AsyncClient, Client
#
# File c:\Users\eyal.farkash\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_api.py:4
#       1 import typing
#       2 from contextlib import contextmanager
# ----> 4 from ._client import Client
#       5 from ._config import DEFAULT_TIMEOUT_CONFIG
#       6 from ._models import Response
#
# File c:\Users\eyal.farkash\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_client.py:9
#       6 from types import TracebackType
#       8 from .__version__ import __version__
# ----> 9 from ._auth import Auth, BasicAuth, FunctionAuth
#      10 from ._compat import asynccontextmanager
#      11 from ._config import (
#      12     DEFAULT_LIMITS,
#      13     DEFAULT_MAX_REDIRECTS,
#    (...)     17     Timeout,
#      18 )
#
# File c:\Users\eyal.farkash\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_auth.py:10
#       7 from urllib.request import parse_http_list
#       9 from ._exceptions import ProtocolError
# ---> 10 from ._models import Request, Response
#      11 from ._utils import to_bytes, to_str, unquote
#      14 class Auth:
#
# File c:\Users\eyal.farkash\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_models.py:1
# ----> 1 import cgi
#       2 import datetime
#       3 import email.message
#
# ModuleNotFoundError: No module named 'cgi'

# %%
load_dotenv()
# Out:
# True

# %%
chat_model = LLM()

# %% [markdown]
# ## Basic String Output
# Before diving into more complex output formats, let's understand how to work with simple string outputs from our Language Model.
# This demonstrates the most basic form of parsing LLM responses.

# %%
messages = [
    SystemMessage(content="Extract the event information."),
    UserMessage(content="Alice and Bob are going to a science fair on Friday.")
]

# %%
ai_message = chat_model.invoke(messages)
ai_message
# Out:
# AIMessage(content='Event: Science Fair  \nParticipants: Alice and Bob  \nDay: Friday', role='assistant', tool_calls=None)

# %%
parser = StrOutputParser()
print(parser.parse(ai_message))
# Out:
# Event: Science Fair
# Participants: Alice and Bob
# Day: Friday

# %% [markdown]
# ## Working with Tools
# Now let's see how we can use tools to get structured outputs from our LLM.
# Tools help us enforce a specific format for the output and make it easier to process programmatically.

# %%
@tool
def calendar_event(name:str, date:str, participants:list[str]):
    """Identify name of the event, date when it will happen and all the participants"""
    return {
        "name": name,
        "date": date,
        "participants": participants
    }

# %%
messages = [
    SystemMessage(content="Extract the event information."),
    UserMessage(content="Alice and Bob are going to a science fair on Friday.")
]

# %%
chat_model_with_tools = LLM(tools=[calendar_event])
ai_message = chat_model_with_tools.invoke(messages)

# %%
# This gives us the variables identified by the LLM
parser = ToolOutputParser()
parser.parse(ai_message)[0]["args"]
# Out:
# {'name': 'Science Fair', 'date': 'Friday', 'participants': ['Alice', 'Bob']}

# %% [markdown]
# ## Using Pydantic Models
# Pydantic provides a powerful way to validate and structure our LLM outputs.
# This approach gives us type safety and data validation out of the box.

# %%
class CalendarEvent(BaseModel):
    """A Pydantic model representing a calendar event.
    
    This model defines the structure for calendar events with validation:
    - name: The name/title of the event
    - date: When the event will occur
    - participants: List of people attending the event
    """

    name: Annotated[str, Field(description="Name/Title of the event. Defaults to ''", default=None)]
    date: Annotated[str, Field(description="Date of the event. Defaults to ''", default=None)]
    participants: Annotated[list[str], Field(description="Who will participate. Defaults to ''", default=None)]

# %%
messages = [
    SystemMessage(content="Extract the event information."),
    UserMessage(content="Alice and Bob are going to a science fair on Friday.")
]

# %%
ai_message = chat_model.invoke(input=messages, response_format=CalendarEvent)
ai_message
# Out:
# AIMessage(content='{"name":"Science Fair","date":"Friday","participants":["Alice","Bob"]}', role='assistant', tool_calls=None)

# %%
# This gives us a structured dictionary we can work with programmatically
parser = JsonOutputParser()
parser.parse(ai_message)
# Out:
# {'name': 'Science Fair', 'date': 'Friday', 'participants': ['Alice', 'Bob']}

# %%
# This gives us a validated Pydantic model with type checking
parser = PydanticOutputParser(model_class=CalendarEvent)
event:CalendarEvent = parser.parse(ai_message)
event
# Out:
# CalendarEvent(name='Science Fair', date='Friday', participants=['Alice', 'Bob'])

# %%
event.participants
# Out:
# ['Alice', 'Bob']
